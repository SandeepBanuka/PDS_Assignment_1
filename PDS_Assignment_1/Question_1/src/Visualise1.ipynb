# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from plotly.tools import FigureFactory as figure

# %%
df=pd.read_csv('/content/processed_data.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Height(in)  Weight(lb)  Age  Grip_strength(kg)  Frailty
# 0           0        65.8         112   30                 30        1
# 1           1        71.5         136   19                 31        1
# 2           2        69.4         153   45                 29        1
# 3           3        68.2         142   22                 28        0
# 4           4        67.8         144   29                 24        0

# %%
df
# Out:
#    Unnamed: 0  Height(in)  Weight(lb)  Age  Grip_strength(kg)  Frailty
# 0           0        65.8         112   30                 30        1
# 1           1        71.5         136   19                 31        1
# 2           2        69.4         153   45                 29        1
# 3           3        68.2         142   22                 28        0
# 4           4        67.8         144   29                 24        0
# 5           5        68.7         123   50                 26        1
# 6           6        69.8         141   51                 22        0
# 7           7        70.1         136   23                 20        0
# 8           8        67.9         112   17                 19        1
# 9           9        66.8         120   39                 31        1

# %%
df.isnull().any()
# Out:
# Unnamed: 0           False
# Height(in)           False
# Weight(lb)           False
# Age                  False
# Grip_strength(kg)    False
# Frailty              False
# dtype: bool

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), cmap='BrBG',fmt='.2f',linewidths=2,annot=True)
# Out:
# <Axes: >
