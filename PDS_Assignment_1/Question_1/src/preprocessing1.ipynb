# %%
import pandas as pd

# %%
data_file=pd.read_csv('/content/Frailtydata.csv')

# %%
data_file.head(5)
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength Frailty
# 0             65.8               112   30             30       N
# 1             71.5               136   19             31       N
# 2             69.4               153   45             29       N
# 3             68.2               142   22             28       Y
# 4             67.8               144   29             24       Y

# %%
data_file
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength Frailty
# 0             65.8               112   30             30       N
# 1             71.5               136   19             31       N
# 2             69.4               153   45             29       N
# 3             68.2               142   22             28       Y
# 4             67.8               144   29             24       Y
# 5             68.7               123   50             26       N
# 6             69.8               141   51             22       Y
# 7             70.1               136   23             20       Y
# 8             67.9               112   17             19       N
# 9             66.8               120   39             31       N

# %%
data_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Height (Inches)   10 non-null     float64
#  1   Weight (Pounds)   10 non-null     int64
#  2   Age               10 non-null     int64
#  3   Grip strength     10 non-null     int64
#  4   Frailty           10 non-null     object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 528.0+ bytes

# %%
data_file.isnull().sum()
# Out:
# Height (Inches)     0
# Weight (Pounds)     0
# Age                 0
# Grip strength       0
# Frailty             0
# dtype: int64

# %%
data_file.describe()
# Out:
#        Height (Inches)  Weight (Pounds)         Age  Grip strength
# count        10.000000         10.000000  10.000000      10.000000
# mean         68.600000        131.900000  32.500000      26.000000
# std           1.670662         14.231811  12.860361       4.521553
# min          65.800000        112.000000  17.000000      19.000000
# 25%          67.825000        120.750000  22.250000      22.500000
# 50%          68.450000        136.000000  29.500000      27.000000
# 75%          69.700000        141.750000  43.500000      29.750000
# max          71.500000        153.000000  51.000000      31.000000

# %%
data_file.columns=['Height(in)', 'Weight(lb)', 'Age', 'Grip_strength(kg)','Frailty']
data_file.columns

# Changing the categorical values into numerical class values
data_file['Frailty'].replace(['Y', 'N'],
                        [0, 1], inplace=True)

# %%
processed_data=data_file.dropna()
processed_data
# Out:
#    Height(in)  Weight(lb)  Age  Grip_strength(kg)  Frailty
# 0        65.8         112   30                 30        1
# 1        71.5         136   19                 31        1
# 2        69.4         153   45                 29        1
# 3        68.2         142   22                 28        0
# 4        67.8         144   29                 24        0
# 5        68.7         123   50                 26        1
# 6        69.8         141   51                 22        0
# 7        70.1         136   23                 20        0
# 8        67.9         112   17                 19        1
# 9        66.8         120   39                 31        1

# %%
processed_data.to_csv('/content/processed_data.csv')
print('Data is processed into a CSV file')
# Out:
# Data is processed into a CSV file
